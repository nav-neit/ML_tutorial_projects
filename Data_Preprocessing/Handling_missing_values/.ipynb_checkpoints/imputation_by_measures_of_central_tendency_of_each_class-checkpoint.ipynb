# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df = pd.read_csv('train.csv')
df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### Dropping those columns that have more than 20% missing data

# %%
null_var = (df.isnull().sum()/df.shape[0])*100
drop_cols = null_var[null_var>20].keys()
df2 = df.drop(columns = drop_cols)
df2.shape
# Out:
# (1460, 76)

# %% [markdown]
# ### Now we select the neumeric variables from our dataframe and form another dataframe

# %%
df2_num = df2.select_dtypes(include=['int64','float64'])
df2_num.shape
# Out:
# (1460, 38)

# %%
 df2_num.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %% [markdown]
# ### Column names that have missing values

# %%
missing_num_cols = [var for var in df2_num.columns if df2_num[var].isnull().sum()>0]
missing_num_cols
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %% [markdown]
# ### View the missing values in the columns

# %%
df2_num[missing_num_cols][df2_num[missing_num_cols].isnull().any(axis=1)]
# Out:
#       LotFrontage  MasVnrArea  GarageYrBlt
# 7             NaN       240.0       1973.0
# 12            NaN         0.0       1962.0
# 14            NaN       212.0       1960.0
# 16            NaN       180.0       1970.0
# 24            NaN         0.0       1968.0
# 31            NaN         0.0       1966.0
# 39           65.0         0.0          NaN
# 42            NaN         0.0       1983.0
# 43            NaN         0.0       1977.0
# 48           33.0         0.0          NaN
# 50            NaN         0.0       1997.0
# 64            NaN       573.0       1998.0
# 66            NaN       287.0       1970.0
# 76            NaN         0.0       1956.0
# 78           72.0         0.0          NaN
# 84            NaN        22.0       1995.0
# 88          105.0         0.0          NaN
# 89           60.0         0.0          NaN
# 95            NaN        68.0       1993.0
# 99           77.0         0.0          NaN
# 100           NaN        28.0       1977.0
# ...

# %% [markdown]
# ### Choosing a categorical variable for the first neumeric columns and checking whether that categorical variable has any null values

# %%
df2['LotConfig'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Finding the number of unique classes in our chosen categorical variable

# %%
df2['LotConfig'].unique()
# Out:
# array(['Inside', 'FR2', 'Corner', 'CulDSac', 'FR3'], dtype=object)

# %% [markdown]
# ### Finding the mean or median of the neumerical variable which corresponds to each class in the chosen categorical variable

# %%
print(df2[df2.loc[:,'LotConfig']=='Inside']['LotFrontage'].mean(),
df2[df2.loc[:,'LotConfig']=='FR2']['LotFrontage'].mean(),
df2[df2.loc[:,'LotConfig']=='Corner']['LotFrontage'].mean(),
df2[df2.loc[:,'LotConfig']=='CulDSac']['LotFrontage'].mean(),
df2[df2.loc[:,'LotConfig']=='FR3']['LotFrontage'].mean())
# Out:
# 67.7156862745098 63.515151515151516 84.03980099502488 59.91111111111111 70.75

# %% [markdown]
# ### Using a loop for the same task

# %%
for label in df2['LotConfig'].unique():
    m=df2[df2.loc[:,'LotConfig']==label]['LotFrontage'].mean()
    print(m)
# Out:
# 67.7156862745098
# 63.515151515151516
# 84.03980099502488
# 59.91111111111111
# 70.75

# %% [markdown]
# ### Replacing the null values in the neumeric columns corresponding to each class with respective mean/median

# %%
m = df2[df2.loc[:,'LotConfig']=='Inside']['LotFrontage'].mean()
df2[df2.loc[:,'LotConfig']=='Inside']['LotFrontage'].replace(np.nan,m)
# Out:
# 0        65.000000
# 2        68.000000
# 5        85.000000
# 6        75.000000
# 8        51.000000
# 10       70.000000
# 11       85.000000
# 12       67.715686
# 13       91.000000
# 17       72.000000
# 18       66.000000
# 19       70.000000
# 21       57.000000
# 22       75.000000
# 23       44.000000
# 24       67.715686
# 27       98.000000
# 29       60.000000
# 30       50.000000
# 33       70.000000
# 34       60.000000
# 35      108.000000
# 37       74.000000
# 38       68.000000
# 39       65.000000
# 40       84.000000
# 41      115.000000
# 44       70.000000
# 45       61.000000
# 47       84.000000
# 48       33.000000
# 49       66.000000
# 51       52.000000
# 53       68.000000
# 54       60.000000
# 55      100.000000
# 56       24.000000
# 59       60.000000
# 60       63.000000
# 61       60.000000
# 62       44.000000
# 63       50.000000
# 64       67.715686
# 65       76.000000
# 66       67.715686
# 67       72.000000
# 70       95.000000
# ...

# %% [markdown]
# ### Using a loop for the same task and updating our dataframe

# %%
for label in df['LotConfig'].unique():
    m = df2[df2.loc[:,'LotConfig']==label]['LotFrontage'].mean()
    df2.update(df2[df2.loc[:,'LotConfig']==label]['LotFrontage'].replace(np.nan,m))

# %% [markdown]
# ### Checking whether the null values got replaced in our neumeric column

# %%
df2['LotFrontage'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Finding the non-null categorical columns corresponding to each neumeric column

# %%
missing_num_cols
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
# WE cannot choose MasVnrType as categorical variable for MasVnrArea
# Because MasVnrType has null values
df2['MasVnrType'].isnull().sum()
# Out:
# 8

# %%
#So we choose another categorical column
df2['Exterior2nd'].isnull().sum()
# Out:
# 0

# %%
#similarly for GarageYrBlt
df2['KitchenQual'].isnull().sum()
# Out:
# 0

# %%
cat_cols = ['LotConfig','Exterior2nd','KitchenQual']

# %% [markdown]
# ### Now we repeat the above tasks for all the neumeric columns

# %%
for cat_var,neum_var in zip(cat_cols,missing_num_cols):
    for label in df[cat_var].unique():
        m = df2[df2.loc[:,cat_var]==label][neum_var].mean()
        df2.update(df2[df2.loc[:,cat_var]==label][neum_var].replace(np.nan,m))

# %% [markdown]
# ### Checking are there any null values present in our neumeric variables

# %%
df2[missing_num_cols].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64
